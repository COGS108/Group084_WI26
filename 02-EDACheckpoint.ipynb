# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
#
# Zhengyin Yang :
#
# Yanbai Li :
#
# Alisa Yang : Analysis - Section 1 Figure 1,2,3
#
# Lily Cheng : Writing-- Section 1 Table 1,2; Figure 4,5,6.
#
# Keyuan Wang:

# %% [markdown]
# # Research Question

# %% [markdown]
# From 2018,2020,2022,2024 at UC San Diego (UCSD), how do transfer-admit selectivity patterns differ across 15 selected majors, and how are these patterns associated with major-level alumni earnings? Using major × year aggregated data, we will characterize selectivity using admitted GPA ranges (converted to midpoint and spread) and admission rates, and we will estimate year-to-year trends for each major. We will then merge in major-level earnings outcomes (25th/median/75th percentile annual earnings and earner counts) for the corresponding year and test whether majors with higher earnings tend to have higher admitted GPA midpoints and/or lower admission rates. Our analysis will use descriptive summaries, trend comparisons, and correlation/OLS regression models (with controls for year, major fixed effects, and applicant volume where available) to assess the strength and significance of these relationships. The final deliverables will identify (1) which majors appear most selective in each year, (2) which majors show the fastest changes in selectivity from 2018,2020,2022,2024, and (3) whether major-level earnings are statistically associated with selectivity measures in this period.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Choosing a university major is a crucial decision that impacts a student's academic trajectory and future career prospects. In recent years, there has been increasing attention to the "return on investment" of higher education, with prospective students often weighing the academic difficulty of a major against its potential graduate earnings. For transfer students—who typically have more defined career goals upon entering university—the competitiveness of admission (measured by the GPA distribution of admitted students (25th, 50th, and 75th percentiles)) is a primary evaluation criterion. This study uses the University of California, San Diego (UCSD) as a case study, a leading public research university where transfer admission selectivity and GPA thresholds vary significantly across different disciplines.
#
# Previous research has confirmed a significant but nuanced link between university admission difficulty and post-graduation earnings. Data from the University of California Information Center suggests this relationship is particularly pronounced at highly competitive institutions like UCSD, especially in fields such as mechanical engineering and computer science, where UC alumni consistently rank among the highest earners five years after graduation. On the other hand, some "pre-professional" majors, such as human biology, maintain high GPA admission thresholds despite potentially lower undergraduate earnings compared to technical fields. This is often because these students go on to pursue advanced medical degrees, indicating that "admission difficulty" is not solely determined by current average salaries but also by long-term academic value.
#
# Labor market conditions and alumni salary signals have also been shown to influence student demand, and consequently, the academic standards required for admission. It is widely believed that students tend to gravitate towards majors perceived to have higher economic returns, such as STEM fields and applied social sciences like business psychology. This shift in demand leads to increased admission difficulty and higher GPA admission thresholds. For example, UCSD's computer science program consistently maintains higher GPA requirements than humanities disciplines like history, directly reflecting its leading position in alumni earnings data.
#
# Despite these observations, there is a lack of localized research specifically examining the year-to-year changes in UCSD's admission GPA distribution and its correlation with real-time average salary trends for specific majors. While general research suggests that a 10% increase in expected salary increases the likelihood of students choosing a particular major by nearly 14% to 18%, it remains unclear whether these enrollment preferences immediately translate into quantifiable changes in the 25th, and 75th percentiles of matriculation GPA. This project aims to bridge the gap between educational enrollment data and labor market wage signals by analyzing fifteen different majors at the University of California, San Diego (UCSD), spanning fields from history to mechanical engineering.
# ### References
#
# 1. University of California. (2025). *Transfers by Major: Admitted GPA and Outcomes*. UC Information Center.
#    https://www.universityofcalifornia.edu/about-us/information-center/transfers-major
#
# 2. BestColleges. (2025). *Does College Selectivity Predict Earnings? Sort of.*
#    https://www.bestcolleges.com/news/does-college-selectivity-predict-earnings/
#
# 3. Baker, R. B., et al. (2018). *The effect of labor market information on community college students’ major choice*. Economics of Education Review.
#    https://edpolicy.umich.edu/sites/epi/files/uploads/02-2017-labor-market-major-choice.pdf
#
# 4. NYU News. (2024). *Study finds that a college degree yields a significant return on investment*.
#    https://www.nyu.edu/about/news-publications/news/2024/march/study-of-5-8-million-americans-finds-that-a-college-degree-yield.html

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that higher post-graduation salaries lead to a larger, more competitive applicant pool, causing a measurable increase in admitted transfer GPAs for that major. We expect to see a positive correlation between changes in major-level median salary and changes in GPA selectivity across the observed period.
#
# Students tend to choose majors with better employment prospects. However, there is a time lag between observing the job market and actually applying. Students applying for the fall 2024 admission are likely to make their decisions based on the salary levels of the 2021-2022 graduates. At UCSD, many majors have enrollment limit. Therefore, the increase in the number of applicants influenced by the previous high income should lead to an increase in the admission GPA threshold in the coming years. We expect this impact to be most significant in computer science and engineering majors.
#
# How we will conduct the test: We will calculate the percentage changes in median salary and the percentile changes in admission GPA. We will conduct a correlation test to determine if the GPA increases more rapidly in professional fields with greater prior salary growth. We will also group the majors by fields (STEM, humanities) and conduct separate regression analyses to examine if there are differences in the relationships between different fields.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# We hypothesize that higher post-graduation salaries lead to a larger, more competitive applicant pool, causing a measurable increase in admitted transfer GPAs for that major. We expect to see a positive correlation between changes in major-level median salary and changes in GPA selectivity across the observed period.
#
# Students tend to choose majors with better employment prospects. However, there is a time lag between observing the job market and actually applying. Students applying for the fall 2024 admission are likely to make their decisions based on the salary levels of the 2021-2022 graduates. At UCSD, many majors have enrollment limit. Therefore, the increase in the number of applicants influenced by the previous high income should lead to an increase in the admission GPA threshold in the coming years. We expect this impact to be most significant in computer science and engineering majors.
#
# How we will conduct the test: We will calculate the percentage changes in median salary and the percentile changes in admission GPA. We will conduct a correlation test to determine if the GPA increases more rapidly in professional fields with greater prior salary growth. We will also group the majors by fields (STEM, humanities) and conduct separate regression analyses to examine if there are differences in the relationships between different fields.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group084_WI26/cef6fe107a44418098ad1f67f63c8df132ba643f/data/00-raw/2018-2024%20Major%20Table.csv', 'filename':'2018-2024 Major Table.csv'},
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group084_WI26/cef6fe107a44418098ad1f67f63c8df132ba643f/data/00-raw/UC%20alumni%20at%20work.csv', 'filename':'UC alumni at work.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading 2018-2024 Major Table.csv:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  5.72it/s]
# Successfully downloaded: 2018-2024 Major Table.csv
# Downloading UC alumni at work.csv:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Overall Download Progress: 100%|██████████| 2/2 [00:00<00:00,  5.67it/s]
# Successfully downloaded: UC alumni at work.csv

# %% [markdown]
# ### Dataset #1
#
# - Dataset #1
#   - Dataset Name: Major Dataset: UCSD Major Selectivity & GPA (2018, 2020, 2022, 2024)
#   - Link to the dataset: https://github.com/COGS108/Group084_WI26/blob/master/data/00-raw/2018-2024%20Major%20Table.csv
#   - Number of observations:60 (15 majors × 4 years)
#   - Number of variables:9 (Year, Major, Applicants, Admits, Enrollees, Admit GPA range, Enrollee GPA range, Admit rate, Yield rate)
#   - Description of the variables most relevant to this project: Admit GPA range: The most crucial variable, expressed as the middle 50% of GPAs for admitted students (e.g., "3.41 – 3.96"). The lower limit (25th percentile) serves as the primary dependent variable, representing the selectivity threshold that is hypothesized to rise in response to high salary outcomes; Applicants: The total number of transfer students who applied to a specific major, serving as the main indicator for measuring project demand; Major: Categorizes the data into specific fields (e.g., humanities, social sciences, life sciences, engineering), allowing for comparison across disciplines; Year: Allows for tracking changes in selectivity and demand over the four time points (2018, 2020, 2022, 2024).
#   - Descriptions of any shortcomings this dataset has with repsect to the project: Aggregated data: The data is grouped by major, preventing analysis of individual student-level factors such as their community college of origin or geographic location; GPA ceiling: Because GPA is capped at 4.0, competitive majors often have an upper bound of 4.00. This creates a hard limit, making it impossible to measure further improvements in the strength of top-tier students; Small sample sizes for some majors: Majors with very few enrolling students are susceptible to significant volatility in their GPA averages, as they can be heavily influenced by the data of just one or two individuals.
#
#
#
#
#
#
# ### Major Dataset: UCSD Major Selectivity & GPA (2018, 2020, 2022, 2024)
#
#
# This dataset contains the admission statistics of transfer students from UCSD for the years 2018, 2020, 2022, and 2024, aggregated by major. The data was extracted from the university's institutional research records and provides a view of the selective trends in admission choices across 15 different majors in the fields of humanities, social sciences, life sciences, and engineering. The data structure consists of each row representing a unique combination of major and year, and all fields have been cleaned and validated for consistency.
#
# The column of applicants represents the total number of transfer students who submitted applications to the specific major during the admission period, and it is the main indicator for measuring the project's demand. Admissions indicate the number of applicants who were admitted. The admission rate is calculated by dividing the number of admissions by the number of applicants, reflecting the competitiveness from the perspective of the institution's enrollment capacity. The enrollment number counts the number of admitted students who eventually enrolled at the University of California, San Diego. The enrollment rate is calculated by dividing the enrollment number by the number of admissions, reflecting the attractiveness of the admission to this major compared to other institutions.
#
# Our assumption holds that the most crucial indicator is the GPA range. The admission GPA range is expressed by the lowest and highest values (for example, "3.41 – 3.96"), which actually represent the middle 50% of the transfer GPAs of admitted students. The lower limit corresponds to the 25th percentile, indicating the GPA required to be a competitive candidate, while the upper limit corresponds to the 75th percentile, showing the GPA of high-performing admitted students. The admission GPA range follows the same structure but reflects the actual admitted students, excluding those who have been admitted to other institutions.
#
# This dataset is directly relevant to our hypothesis regarding salary-driven competition. The Admit GPA range, specifically the 25th and 75th percentiles, serves as our primary dependent variable, representing the selectivity threshold we hypothesize will rise in response to strong labor market signals. An increase in applicants in specific major driven by high salary outcomes should force admissions officers to raise the GPA floor. We can observe this by tracking changes in the lower bound of the Admit GPA range over time.
#
# Several limitations of this dataset should be noted. The data is grouped by major, so we cannot see individual student information like which community college they came from or where they live. Since GPA cannot go above 4.0, competitive majors like mechanical engineering often has upper bound 4.00, so if top students get even stronger, we cannot measure that improvement because the scale has a hard limit. Some majors have very few enrolling students, so their GPA averages can swing wildly based on just one or two people. Also, we assume that every person here is rational, who makes decisions and holds beliefs based on logic, objective facts, and evidence rather than on emotions or impulses. But in reality, we have to admit that people aren't always rational, and thier major choices may not just simply be the best out of their choices and strengths.

# %% [markdown]
# #### Outlier & Suspicious Entry Flags

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import re
import scipy.stats as stats
import os

if "df_major" not in globals():
    proc_path = "data/02-processed/major_processed.csv"
    if os.path.exists(proc_path):
        df_major = pd.read_csv(proc_path, encoding="utf-8-sig")
    else:
        df_major = build_df_major(save=True)
df_major_flag = df_major.copy()
rules = []
rules.append(("bad_year", ~df_major_flag["year"].isin([2018, 2020, 2022, 2024])))
if "admit_rate" in df_major_flag.columns:
    rules.append(("bad_admit_rate", (df_major_flag["admit_rate"] < 0) | (df_major_flag["admit_rate"] > 1)))
if "yield_rate" in df_major_flag.columns:
    rules.append(("bad_yield_rate", (df_major_flag["yield_rate"] < 0) | (df_major_flag["yield_rate"] > 1)))

for c in ["applicants", "admits", "enrollees"]:
    if c in df_major_flag.columns:
        rules.append((f"neg_{c}", df_major_flag[c] < 0))

if set(["applicants","admits"]).issubset(df_major_flag.columns):
    rules.append(("admits_gt_applicants", df_major_flag["admits"] > df_major_flag["applicants"]))
if set(["enrollees","admits"]).issubset(df_major_flag.columns):
    rules.append(("enrollees_gt_admits", df_major_flag["enrollees"] > df_major_flag["admits"]))
if "gpa_mid" in df_major_flag.columns:
    rules.append(("bad_gpa_mid", (df_major_flag["gpa_mid"] < 0) | (df_major_flag["gpa_mid"] > 4.5)))

def flag_iqr_outliers(s, k=1.5):
    s = s.dropna()
    if len(s) < 6:
        return pd.Series(False, index=s.index) 
    q1, q3 = s.quantile([0.25, 0.75])
    iqr = q3 - q1
    lo, hi = q1 - k * iqr, q3 + k * iqr
    return (s < lo) | (s > hi)

iqr_cols = [c for c in ["applicants","admits","enrollees","gpa_mid","admit_rate","yield_rate"] if c in df_major_flag.columns]
for col in iqr_cols:
    mask = (
        df_major_flag.groupby("year", group_keys=False)[col]
        .apply(lambda s: flag_iqr_outliers(s, k=1.5))
    )
    df_major_flag[f"out_{col}_iqr"] = False
    df_major_flag.loc[mask.index, f"out_{col}_iqr"] = mask

df_major_flag["suspicious_reasons"] = ""
for name, cond in rules:
    df_major_flag.loc[cond.fillna(False), "suspicious_reasons"] += f"{name};"

for col in iqr_cols:
    flag_col = f"out_{col}_iqr"
    df_major_flag.loc[df_major_flag[flag_col] == True, "suspicious_reasons"] += f"{flag_col};"

df_major_flag["is_suspicious"] = df_major_flag["suspicious_reasons"].str.len() > 0
print("Suspicious rows (major):", df_major_flag["is_suspicious"].sum())
display(df_major_flag[df_major_flag["is_suspicious"]].head(30))
# Out:
# Suspicious rows (major): 13
#     year                          major  applicants  admits  enrollees  \
# 6   2024              Cognitive Science         358     294        140
# 14  2024         Mechanical Engineering         546     138         44
# 20  2022                 Bioengineering          77      21          9
# 21  2022              Cognitive Science         313     257        107
# 29  2022         Mechanical Engineering         441      38          8
# 36  2020              Cognitive Science         278     195         86
# 44  2020         Mechanical Engineering         540     149         40
# 49  2018    Electrical Engineering - BS         435     221         69
# 51  2018              Cognitive Science         254     173         73
# 54  2018             Literature/Writing         101      57         14
# 57  2018                 Marine Biology         126      61         36
# 58  2018  Ecology, Behavior & Evolution          66      22          4
# 59  2018         Mechanical Engineering         560     137         76
#
#     admit_rate  yield_rate admit_gpa_range enrollee_gpa_range  gpa_low  ...  \
# 6         0.82        0.48     3.50 - 3.93        3.38 - 3.90     3.50  ...
# 14        0.25        0.32     3.80 - 4.00        3.74 - 3.91     3.80  ...
# 20        0.27        0.43     3.85 - 3.98        3.52 - 3.98     3.85  ...
# 21        0.82        0.42     3.43 - 3.90        3.37 - 3.82     3.43  ...
# 29        0.09        0.21     3.95 - 4.00        3.97 - 4.00     3.95  ...
# 36        0.70        0.44     3.42 - 3.87        3.36 - 3.77     3.42  ...
# 44        0.28        0.27     3.73 - 4.00        3.68 - 3.90     3.73  ...
# 49        0.51        0.31     3.48 - 3.88        3.38 - 3.74     3.48  ...
# 51        0.68        0.42     3.25 - 3.73        3.25 - 3.56     3.25  ...
# 54        0.56        0.25     3.41 - 3.86        3.37 - 3.63     3.41  ...
# 57        0.48        0.59     3.19 - 3.62        3.32 - 3.51     3.19  ...
# 58        0.33        0.18     3.35 - 3.77           redacted     3.35  ...
# 59        0.24        0.55     3.50 - 3.80        3.45 - 3.73     3.50  ...
#
#     gpa_mid  gpa_width  out_applicants_iqr  out_admits_iqr  out_enrollees_iqr  \
# 6     3.715       0.43               False            True               True
# 14    3.900       0.20               False           False              False
# 20    3.915       0.13               False           False              False
# 21    3.665       0.47               False           False               True
# 29    3.975       0.05               False           False              False
# 36    3.645       0.45               False           False               True
# 44    3.865       0.27                True           False              False
# 49    3.680       0.40                True           False               True
# 51    3.490       0.48               False           False               True
# 54    3.635       0.45               False           False               True
# 57    3.405       0.43               False           False              False
# 58    3.560       0.42               False           False               True
# 59    3.650       0.30                True           False               True
#
#     out_gpa_mid_iqr  out_admit_rate_iqr  out_yield_rate_iqr  \
# 6             False               False               False
# 14             True               False               False
# 20             True               False               False
# 21            False               False               False
# 29             True               False               False
# 36            False               False               False
# 44            False               False               False
# 49            False               False               False
# 51            False               False               False
# 54            False               False               False
# 57             True               False               False
# 58            False               False               False
# 59            False               False               False
#
#                        suspicious_reasons is_suspicious
# 6       out_admits_iqr;out_enrollees_iqr;          True
# 14                       out_gpa_mid_iqr;          True
# 20                       out_gpa_mid_iqr;          True
# 21                     out_enrollees_iqr;          True
# 29                       out_gpa_mid_iqr;          True
# 36                     out_enrollees_iqr;          True
# 44                    out_applicants_iqr;          True
# 49  out_applicants_iqr;out_enrollees_iqr;          True
# 51                     out_enrollees_iqr;          True
# 54                     out_enrollees_iqr;          True
# 57                       out_gpa_mid_iqr;          True
# 58                     out_enrollees_iqr;          True
# 59  out_applicants_iqr;out_enrollees_iqr;          True
#
# [13 rows x 21 columns]

# %% [markdown]
# #### Tidy and Clean Data

# %%
import os, re
import numpy as np
import pandas as pd

# ---- paths (repo template folders) ----
RAW_DIR  = "data/00-raw"
PROC_DIR = "data/02-processed"
os.makedirs(PROC_DIR, exist_ok=True)

major_path = os.path.join(RAW_DIR, "2018-2024 Major Table.csv")

# ---- read raw ----
df_major_raw = pd.read_csv(
    major_path,
    encoding="utf-8-sig",
    sep=",",
    engine="python"
)

print("Major raw shape:", df_major_raw.shape)
display(df_major_raw.head())

# ---- helpers ----
def to_numeric_percent(x):
    """'75%' -> 0.75, '0.75' -> 0.75, NaN stays NaN"""
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    if s == "":
        return np.nan
    s = s.replace("%", "").strip()
    try:
        v = float(s)
    except Exception:
        return np.nan
    # if user stored 75 instead of 0.75
    if v > 1.0:
        v = v / 100.0
    return v

def parse_gpa_range(x):
    """
    '3.41 - 3.96' -> (3.41, 3.96)
    robust to dash variants: '-', '–', '—'
    returns (nan, nan) if fails
    """
    if pd.isna(x):
        return (np.nan, np.nan)
    s = str(x).strip()
    if s == "":
        return (np.nan, np.nan)

    # normalize dash variants to '-'
    s = s.replace("–", "-").replace("—", "-")

    # extract numbers (handles ints or decimals)
    nums = re.findall(r"\d+(?:\.\d+)?", s)
    if len(nums) >= 2:
        lo = float(nums[0])
        hi = float(nums[1])
        if lo > hi:
            lo, hi = hi, lo
        return (lo, hi)
    return (np.nan, np.nan)

def standardize_major_name(x):
    """basic cleanup; keep it conservative"""
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    s = re.sub(r"\s+", " ", s)
    return s

# ---- rename columns to a consistent schema ----
rename_map = {
    "Year": "year",
    "Major": "major",
    "Applicants": "applicants",
    "Admits": "admits",
    "Enrollees": "enrollees",
    "Admit GPA range": "admit_gpa_range",
    "Enrollee GPA range": "enrollee_gpa_range",
    "Admit rate": "admit_rate",
    "Yield rate": "yield_rate",
}

df_major = df_major_raw.rename(columns=rename_map).copy()

# Strip any accidental whitespace in column names
df_major.columns = df_major.columns.str.strip()

# ---- keep only columns that exist (from the raw schema) ----
base_cols = [c for c in rename_map.values() if c in df_major.columns]
df_major = df_major[base_cols].copy()

# ---- type cleaning ----
if "year" in df_major.columns:
    df_major["year"] = pd.to_numeric(df_major["year"], errors="coerce").astype("Int64")

if "major" in df_major.columns:
    df_major["major"] = df_major["major"].apply(standardize_major_name)

# numeric count columns
for c in ["applicants", "admits", "enrollees"]:
    if c in df_major.columns:
        df_major[c] = pd.to_numeric(df_major[c], errors="coerce")

# percent columns
for c in ["admit_rate", "yield_rate"]:
    if c in df_major.columns:
        df_major[c] = df_major[c].apply(to_numeric_percent)

# ---- GPA range parsing -> gpa_low/high/mid/width ----
if "admit_gpa_range" in df_major.columns:
    lo_hi = df_major["admit_gpa_range"].apply(parse_gpa_range)
    df_major["gpa_low"]   = lo_hi.apply(lambda t: t[0])
    df_major["gpa_high"]  = lo_hi.apply(lambda t: t[1])
    df_major["gpa_mid"]   = (df_major["gpa_low"] + df_major["gpa_high"]) / 2
    df_major["gpa_width"] = df_major["gpa_high"] - df_major["gpa_low"]

# ---- filter years (match your project years) ----
YEARS = [2018, 2020, 2022, 2024]
if "year" in df_major.columns:
    df_major = df_major[df_major["year"].isin(YEARS)].copy()

# ---- drop rows missing key identifiers ----
df_major = df_major.dropna(subset=["year", "major"]).copy()

# ---- final column order (includes derived GPA cols) ----
final_cols = [
    "year", "major",
    "applicants", "admits", "enrollees",
    "admit_rate", "yield_rate",
    "admit_gpa_range", "enrollee_gpa_range",
    "gpa_low", "gpa_high", "gpa_mid", "gpa_width",
]
final_cols = [c for c in final_cols if c in df_major.columns]
df_major = df_major[final_cols].copy()

print("Major cleaned shape:", df_major.shape)
display(df_major.head(10))

miss = df_major.isna().mean().sort_values(ascending=False)
print("Major missingness (fraction):")
display(miss)

# sanity checks for gpa_mid existence
print("Has gpa_mid?", "gpa_mid" in df_major.columns)
if "gpa_mid" in df_major.columns:
    print("gpa_mid missing:", df_major["gpa_mid"].isna().mean())

# ---- save processed ----
major_out = os.path.join(PROC_DIR, "major_processed.csv")
df_major.to_csv(major_out, index=False, encoding="utf-8-sig")
print("Saved:", major_out)
# Out:
# Major raw shape: (60, 9)
#    Year                        Major  Applicants  Admits  Enrollees  \
# 0  2024                      History         284     212         24
# 1  2024          Visual Arts - Media         263     176         63
# 2  2024         Computer Engineering         455     137         61
# 3  2024                    Chemistry         190      89         28
# 4  2024  Electrical Engineering - BS         412     161         68
#
#   Admit GPA range Enrollee GPA range Admit rate Yield rate
# 0     3.41 - 3.96        3.16 - 3.72        75%        11%
# 1     3.41 - 3.88        3.44 - 3.82        67%        36%
# 2     3.70 - 3.97        3.72 - 3.93        30%        45%
# 3     3.41 - 3.98        3.40 - 3.69        47%        31%
# 4     3.51 - 3.95        3.40 - 3.82        39%        42%
# Major cleaned shape: (60, 13)
#    year                        major  applicants  admits  enrollees  \
# 0  2024                      History         284     212         24
# 1  2024          Visual Arts - Media         263     176         63
# 2  2024         Computer Engineering         455     137         61
# 3  2024                    Chemistry         190      89         28
# 4  2024  Electrical Engineering - BS         412     161         68
# 5  2024               Bioengineering          95      41         14
# 6  2024            Cognitive Science         358     294        140
# 7  2024                Public Health         217     128         56
# 8  2024          Applied Mathematics         194     143         46
# 9  2024           Literature/Writing         153      90         13
#
#    admit_rate  yield_rate admit_gpa_range enrollee_gpa_range  gpa_low  \
# 0        0.75        0.11     3.41 - 3.96        3.16 - 3.72     3.41
# 1        0.67        0.36     3.41 - 3.88        3.44 - 3.82     3.41
# 2        0.30        0.45     3.70 - 3.97        3.72 - 3.93     3.70
# 3        0.47        0.31     3.41 - 3.98        3.40 - 3.69     3.41
# 4        0.39        0.42     3.51 - 3.95        3.40 - 3.82     3.51
# 5        0.43        0.34     3.74 - 3.98        3.62 - 3.91     3.74
# 6        0.82        0.48     3.50 - 3.93        3.38 - 3.90     3.50
# 7        0.59        0.44     3.34 - 3.81        3.25 - 3.61     3.34
# 8        0.74        0.32     3.55 - 3.97        3.32 - 3.80     3.55
# 9        0.59        0.14     3.43 - 3.90        3.24 - 3.82     3.43
#
#    gpa_high  gpa_mid  gpa_width
# 0      3.96    3.685       0.55
# 1      3.88    3.645       0.47
# 2      3.97    3.835       0.27
# 3      3.98    3.695       0.57
# 4      3.95    3.730       0.44
# 5      3.98    3.860       0.24
# 6      3.93    3.715       0.43
# 7      3.81    3.575       0.47
# 8      3.97    3.760       0.42
# 9      3.90    3.665       0.47
# Major missingness (fraction):
# year                  0.0
# major                 0.0
# applicants            0.0
# admits                0.0
# enrollees             0.0
# admit_rate            0.0
# yield_rate            0.0
# admit_gpa_range       0.0
# enrollee_gpa_range    0.0
# gpa_low               0.0
# gpa_high              0.0
# gpa_mid               0.0
# gpa_width             0.0
# dtype: float64
# Has gpa_mid? True
# gpa_mid missing: 0.0
# Saved: data/02-processed/major_processed.csv

# %% [markdown]
# ### Dataset #2
# - Dataset #2
#   - Dataset Name: Earnings Dataset: UCSD Alumni Earnings by Major (2018,2020, 2022, 2024).
#   - Link to the dataset: https://github.com/COGS108/Group084_WI26/blob/master/data/00-raw/UC%20alumni%20at%20work.csv
#   - Number of observations:60(15 majors × 4 year groups)
#   - Number of variables:4(75%, 50%, 25% of annual earnings; Count of Number of Records)
#   - Description of the variables most relevant to this project:
#      The top tier(75%) low tier(25%) and average (50% / median) annual earning for a typical UCSD alumni whom graduated in 2015-2016, 2017-2018, 2019-2020, and 2021-2022, aggregated by major. Note that the annual salaries here have been adjusted to 2024 dollar, and represents the average annual salaries UC bachelor degree owners earned within 2 years of graduation.
#
#      Count of Number of Records. Is the numbers of UCSD alumni that give permission for UCSD to record and use their data anonymously.
#
#   - Descriptions of any shortcomings this dataset has with repsect to the project:
#      This data is based on the Count of Number of Records, which many whom didn’t earn quite a good living would tend to not be on the record. Though we try our best to choose the represent majors, some rows have very few of UCSD alumni being recorded, for example, there is only 30 people are recorded in chemistry in 2015-2016 so their salary averages can swing wildly. Also, this dataset consider UC San Diego alumni only, which whom may not be the only person a UCSD undergrad reach out to and thier salary might not be the only salary a UCSD undergrad refer to.
#
#
#
#
#
#
#
# ### Earnings Dataset: UCSD Alumni Earnings by Major (2018,2020, 2022, 2024)
#
# This dataset contains the admission statistics of annual earning for a typical UCSD alumni whom graduated in 2015-2016, 2017-2018, 2019-2020, and 2021-2022, aggregated by major. The data was extracted from the UC alumni at work website.Note that the average annual salaries UCSD bachelor degree owners earned within 2 years of graduation.
#
# This dataset has 15 different majors across the wide fields of humanities, social sciences, life sciences, and engineering. The rows represent a unique combination of major and year, and all fields have been cleaned and validated for consistency. The column of earnings percentile 75, median, and percentile 25, gives us an overall view of how the annual earnings would look like for a student who earned a bachelor in a specific major, didn’t go to any graduate school and work directly for 2 years. Count of Number of Records is the number of UCSD alumni that are recorded. Which quite matches the reality of engineering students tend and more easily to get a job right after undergrad, while natural science and art degrees are more likely pursuing a higher degree. We also try using the rate of records, which means the count of number of records divided by the overall graduated where we can’t find the specific data of UCSD alumni numbers in a specific major (only departments’ count).
#
# So, 1. for a certain major; (when the median doesn't have a significant change), if the 75% earning goes higher or the 25% earning goes lower, then it means for at least UCSD alumni, this field might be more promising(more money, more job opening, and possible eaiser internships and recruial). And thus under our H0, there shall be a upward shift in the numbers of studnet who choose this major if this major earnings is continously going higher(50%/median earning increase) / having a higher ceiling (75% earning increase) or higher bottom line (25% earning increase)
#
# As noted above, the annual earnings here are in unit of adjusted US dollars, which means adjusting the salaries of previous years base on the ratio between the US current that year to 2024 year. The calculation behind it is a little bit complex, basic ideas is to find out how much money you need to spend in that year to buy for example an egg(buying power). You can use website like [CPI Inflation Calculator](https://www.bls.gov/data/inflation_calculator.htm) to do it.
#
# Several limitations of this dataset should be noted. This data is based on the Count of Number of Records, which many whom didn’t earn quite a good living would tend to not be on the record. Though we try our best to choose the represent majors, some rows have very few of UCSD alumni being recorded, for example, there is only 30 people are recorded in chemistry in 2015-2016 so their salary averages can swing wildly. Also, we are considering UC San Diego alumni's salary here only, but in reality, the students here may not just get the overall sense of a carrer's salary by looking up their own school's salary summery or by networking within their school, they may also connect with other people who aren't UCSD alumni, and get a sense of what the salary may look at from them. As different schools may have different recognized majors, and this ego effect might also affect the annual salaries one may earned, if the student reach out to someone who isn't a UCSD alumni, its possible that they may get a different number or overall sense of what the salary who look at for a typical B.S/ B.A holder in that speific major.

# %% [markdown]
# #### Outlier & Suspicious Entry Flags

# %%
if "df_earn" not in globals():

    # match your actual saved filename
    proc_path = "data/02-processed/earnings_processed.csv"
    raw_path  = "data/00-raw/UC alumni at work.csv"

    if os.path.exists(proc_path):
        df_earn = pd.read_csv(proc_path, encoding="utf-8-sig")
        print("Loaded df_earn from processed:", proc_path)

    elif os.path.exists(raw_path):
        df_earn_raw = pd.read_csv(raw_path, encoding="utf-8-sig", sep=",", engine="python")
        print("Loaded df_earn from raw:", raw_path)

        df_earn_raw.columns = df_earn_raw.columns.str.strip()

        rename_map = {
            "Year": "year",
            "Major": "major",
            "Median Annual Earnings": "earn_med",
            "Percentile (25) of Annual Earnings": "earn_p25",
            "Percentile (75) of Annual Earnings": "earn_p75",
            "Earners Count": "earners_count",
            "Count of Number of Records": "records_count",
        }
        df_earn = df_earn_raw.rename(columns={k:v for k,v in rename_map.items() if k in df_earn_raw.columns}).copy()

        def normalize_year(x):
            if pd.isna(x):
                return np.nan
            s = str(x).strip()
            m = re.match(r"^\s*(\d{4})\s*-\s*(\d{4})\s*$", s)
            if m:
                return int(m.group(2))
            try:
                return int(float(s))
            except:
                return np.nan

        if "year" in df_earn.columns:
            df_earn["year"] = df_earn["year"].apply(normalize_year).astype("Int64")

    else:
        raise FileNotFoundError(
            "Cannot find processed or raw earnings file. Run get_data.get_raw(...) first."
        )

df_earn_flag = df_earn.copy()
df_earn_flag.columns = df_earn_flag.columns.str.strip()

if "year" not in df_earn_flag.columns and "Year" in df_earn_flag.columns:
    df_earn_flag = df_earn_flag.rename(columns={"Year": "year"})

rules = []

if "year" in df_earn_flag.columns:
    rules.append(("bad_year", ~df_earn_flag["year"].isin([2018, 2020, 2022, 2024])))
else:
    print("Warning: no 'year' column found; skipping bad_year rule.")

for c in ["earn_p25", "earn_med", "earn_p75"]:
    if c in df_earn_flag.columns:
        rules.append((f"neg_{c}", df_earn_flag[c] < 0))
        rules.append((f"too_big_{c}", df_earn_flag[c] > 1_000_000))

if set(["earn_p25", "earn_med"]).issubset(df_earn_flag.columns):
    rules.append(("p25_gt_med", df_earn_flag["earn_p25"] > df_earn_flag["earn_med"]))
if set(["earn_med", "earn_p75"]).issubset(df_earn_flag.columns):
    rules.append(("med_gt_p75", df_earn_flag["earn_med"] > df_earn_flag["earn_p75"]))

for c in ["earners_count", "records_count"]:
    if c in df_earn_flag.columns:
        rules.append((f"neg_{c}", df_earn_flag[c] < 0))

def flag_iqr_outliers(s, k=1.5):
    s = s.dropna()
    if len(s) < 6:
        return pd.Series(False, index=s.index)
    q1, q3 = s.quantile([0.25, 0.75])
    iqr = q3 - q1
    lo, hi = q1 - k * iqr, q3 + k * iqr
    return (s < lo) | (s > hi)

iqr_cols = [c for c in ["earn_p25", "earn_med", "earn_p75", "earners_count"] if c in df_earn_flag.columns]

if "year" in df_earn_flag.columns:
    for col in iqr_cols:
        mask = (
            df_earn_flag.groupby("year", group_keys=False)[col]
            .apply(lambda s: flag_iqr_outliers(s, k=1.5))
        )
        df_earn_flag[f"out_{col}_iqr"] = False
        df_earn_flag.loc[mask.index, f"out_{col}_iqr"] = mask
else:
    print("Warning: no 'year' column found; skipping IQR-by-year outliers.")

df_earn_flag["suspicious_reasons"] = ""
for name, cond in rules:
    df_earn_flag.loc[cond.fillna(False), "suspicious_reasons"] += f"{name};"

for col in iqr_cols:
    flag_col = f"out_{col}_iqr"
    if flag_col in df_earn_flag.columns:
        df_earn_flag.loc[df_earn_flag[flag_col] == True, "suspicious_reasons"] += f"{flag_col};"

df_earn_flag["is_suspicious"] = df_earn_flag["suspicious_reasons"].str.len() > 0

print("Suspicious rows (earnings):", df_earn_flag["is_suspicious"].sum())
display(df_earn_flag[df_earn_flag["is_suspicious"]].head(30))
# Out:
# Loaded df_earn from processed: data/02-processed/earnings_processed.csv
# Suspicious rows (earnings): 6
#     year                        major  earn_med  earn_p25  earn_p75  \
# 2   2024         Computer Engineering  104844.0   76024.0  160505.0
# 4   2024  Electrical Engineering - BS   92359.0   79534.0  113449.0
# 17  2022         Computer Engineering  116188.0   78670.0  156585.0
# 21  2022            Cognitive Science   59401.0   41686.0   81054.0
# 32  2020         Computer Engineering  121057.0   95474.0  160247.0
# 47  2018         Computer Engineering  109959.0   88017.0  145813.0
#
#     earners_count  records_count  out_earn_p25_iqr  out_earn_med_iqr  \
# 2             156            156             False             False
# 4             172            172             False             False
# 17            127            127             False             False
# 21            254            254             False             False
# 32            174            174             False             False
# 47            174            174             False             False
#
#     out_earn_p75_iqr  out_earners_count_iqr  \
# 2               True                   True
# 4              False                   True
# 17              True                  False
# 21             False                   True
# 32              True                  False
# 47              True                  False
#
#                          suspicious_reasons  is_suspicious
# 2   out_earn_p75_iqr;out_earners_count_iqr;           True
# 4                    out_earners_count_iqr;           True
# 17                        out_earn_p75_iqr;           True
# 21                   out_earners_count_iqr;           True
# 32                        out_earn_p75_iqr;           True
# 47                        out_earn_p75_iqr;           True

# %% [markdown]
# #### Tidy and Clean Data

# %%
import os, re
import numpy as np
import pandas as pd

RAW_DIR = "data/00-raw"
PROC_DIR = "data/02-processed"
os.makedirs(PROC_DIR, exist_ok=True)
earn_path = os.path.join(RAW_DIR, "UC alumni at work.csv")

df_earn_raw = pd.read_csv(
    earn_path,
    encoding="utf-8-sig",
    sep=",",
    engine="python",
)
print("Earnings raw shape:", df_earn_raw.shape)
display(df_earn_raw.head())

def standardize_major_name(x):
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    s = re.sub(r"\s+", " ", s)
    return s

def to_numeric_money(x):
    """handles '120,548' or '$120,548' etc."""
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    if s == "":
        return np.nan
    s = s.replace("$", "").replace(",", "")
    try:
        return float(s)
    except:
        return np.nan

rename_map = {
    "Year": "year",
    "Major": "major",
    "Median Annual Earnings": "earn_med",
    "Percentile (25) of Annual Earnings": "earn_p25",
    "Percentile (75) of Annual Earnings": "earn_p75",
    "Earners Count": "earners_count",
    "Count of Number of Records": "records_count",
}
df_earn = df_earn_raw.rename(columns=rename_map).copy()

keep_cols = [c for c in rename_map.values() if c in df_earn.columns]
df_earn = df_earn[keep_cols].copy()
def normalize_year(x):
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    m = re.match(r"^\s*(\d{4})\s*-\s*(\d{4})\s*$", s)
    if m:
        return int(m.group(2))
    try:
        return int(float(s))
    except:
        return np.nan

df_earn["year"] = df_earn["year"].apply(normalize_year).astype("Int64")
df_earn["major"] = df_earn["major"].apply(standardize_major_name)

for c in ["earn_med", "earn_p25", "earn_p75"]:
    if c in df_earn.columns:
        df_earn[c] = df_earn[c].apply(to_numeric_money)
for c in ["earners_count", "records_count"]:
    if c in df_earn.columns:
        df_earn[c] = pd.to_numeric(df_earn[c], errors="coerce")

YEARS = [2018, 2020, 2022, 2024]
df_earn = df_earn[df_earn["year"].isin(YEARS)].copy()

df_earn = df_earn.dropna(subset=["year", "major"]).copy()

print("Earnings cleaned shape:", df_earn.shape)
display(df_earn.head(10))

miss = df_earn.isna().mean().sort_values(ascending=False)
print("Earnings missingness (fraction):")
display(miss)

earn_out = os.path.join(PROC_DIR, "earnings_processed.csv")
df_earn.to_csv(earn_out, index=False, encoding="utf-8-sig")
print("Saved:", earn_out)
# Out:
# Earnings raw shape: (60, 7)
#    Year                        Major  Percentile (75) of Annual Earnings  \
# 0  2024                      History                               49697
# 1  2024          Visual Arts - Media                               49000
# 2  2024         Computer Engineering                              160505
# 3  2024                    Chemistry                               71287
# 4  2024  Electrical Engineering - BS                              113449
#
#    Median Annual Earnings  Percentile (25) of Annual Earnings  Earners Count  \
# 0                   35933                               21804             61
# 1                   36057                               20440             60
# 2                  104844                               76024            156
# 3                   56269                               48061             80
# 4                   92359                               79534            172
#
#    Count of Number of Records
# 0                          61
# 1                          60
# 2                         156
# 3                          80
# 4                         172
# Earnings cleaned shape: (60, 7)
#    year                        major  earn_med  earn_p25  earn_p75  \
# 0  2024                      History   35933.0   21804.0   49697.0
# 1  2024          Visual Arts - Media   36057.0   20440.0   49000.0
# 2  2024         Computer Engineering  104844.0   76024.0  160505.0
# 3  2024                    Chemistry   56269.0   48061.0   71287.0
# 4  2024  Electrical Engineering - BS   92359.0   79534.0  113449.0
# 5  2024               Bioengineering   61865.0   39206.0   83579.0
# 6  2024            Cognitive Science   44596.0   30211.0   67291.0
# 7  2024                Public Health   45419.0   29155.0   62040.0
# 8  2024          Applied Mathematics   56440.0   32556.0   72668.0
# 9  2024           Literature/Writing   38368.0   27740.0   50520.0
#
#    earners_count  records_count
# 0             61             61
# 1             60             60
# 2            156            156
# 3             80             80
# 4            172            172
# 5             40             40
# 6            153            153
# 7             62             62
# 8             60             60
# 9             71             71
# Earnings missingness (fraction):
# year             0.0
# major            0.0
# earn_med         0.0
# earn_p25         0.0
# earn_p75         0.0
# earners_count    0.0
# records_count    0.0
# dtype: float64
# Saved: data/02-processed/earnings_processed.csv

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# ### Section 1 of EDA - Analyze UCSD Major Selectivity and Alumni Earnings respectively

# %% [markdown]
# ###Fig1.
#
# There is a clear patterns in how transfer GPAs have changed at UCSD between 2018 and 2024. GPA requirements have gone up across almost all majors over this period. In 2018, GPAs ranged from 2.95 (marine biology) to 3.65 (bioengineering), but by 2024, the lowest was 3.3 (marine biology) and the highest was 3.9 (mechanical engineering and bioengineering), showing that even less competitive majors now require higher GPAs than they did six years ago.
# Some majors stand out with particularly large increases. Most obviously, mechanical engineering started at 3.40 in 2018 and climbed to 3.90 by 2024.
# Looking at field differences, engineering majors consistently sit at the top across all four years—mechanical, bioengineering, and computer engineering are almost always in the top five. Arts and humanities majors stay in the middle, with GPAs mostly between 3.2 and 3.5, while biological sciences are at the bottom every year, though their GPAs have crept up over time.
# These patterns is relevant to whether majors with higher earnings attract more competitive applicants. Engineering fields consistently show the highest GPAs across all years. The year-to-year variation we see in some majors, such as electrical engineering and public health, may make it harder to detect clear statistical relationships with earnings data. However, the overall upward trend across most majors provides enough movement to test whether GPAs increase faster in fields with higher salaries.

# %%
def rank_bar(df, year, col, title, ascending=False):
    sub = df[df["year"] == year].dropna(subset=[col]).sort_values(col, ascending=ascending)
    plt.figure(figsize=(10,5))
    plt.bar(sub["major"], sub[col])
    plt.xticks(rotation=60, ha="right")
    plt.title(title)
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

years = sorted(df["year"].dropna().unique().tolist())

for y in years:
    rank_bar(df, y, "gpa_mid", f"GPA Midpoint by Major ({y})", ascending=False)

# %% [markdown]
# ###Fig2.
#
# In 2018, the most selective majors were mechanical engineering at 0.24, bioengineering at 0.31, and ecology, behavior & evolution at 0.33. The least selective were cognitive science at 0.69, computer engineering at 0.64, and history at 0.60. In 2020, mechanical engineering remained most selective at 0.28, followed by marine biology at 0.30 and ecology, behavior & evolution at 0.41. Bioengineering dropped to 0.42. The least selective were history at 0.67, cognitive science at 0.66, and drama at 0.63. In 2022, selectivity tightened considerably for some majors. Mechanical engineering dropped to 0.11, making it far more selective than any other major that year. Bioengineering followed at 0.27 and computer engineering at 0.34. Marine biology sat at 0.41. The least selective was cognitive science at 0.80, followed by history at 0.70 and visual arts, media at 0.69. In 2024, mechanical engineering was back to 0.24, with computer engineering at 0.31 and electrical engineering at 0.39. Marine biology was at 0.42, bioengineering at 0.45. The least selective were cognitive science at 0.81, history at 0.75, and applied mathematics at 0.74.
# Some majors show interesting patterns. Mechanical engineering consistently has the lowest or among the lowest admit rates across all four years, making it the most selective by this measure. Computer engineering became more selective over time, moving from 0.64 in 2018 to 0.31 in 2024. Cognitive science remains the least selective or near the bottom every year, with admit rates between 0.66 and 0.81, meaning it accepts a much higher percentage of applicants than other majors.
# Looking at field differences, engineering majors dominate the most selective end, with mechanical, bioengineering, and computer engineering consistently appearing among the lowest admit rates. Biological sciences like marine biology and ecology show mid-range selectivity but can fluctuate. Arts and humanities majors cluster at the higher end of admit rates, meaning they are less selective.
# These patterns reveals whether majors with higher earnings attract more competitive applicants. Engineering fields typically leading to higher-paying jobs, is consistent with lowest admit rates across all years. The rise of computer engineering as more selective over time also fits this pattern. The year-to-year swings in some majors like marine biology may reflect factors beyond applicant quality, such as changes in program capacity. But overall, the data shows that fields with stronger earnings potential tend to admit a smaller percentage of transfer applicants.

# %%
for y in years:
    rank_bar(df, y, "admit_rate", f"Admit Rate by Major ({y}) (lower = more selective)", ascending=True)

# %% [markdown]
# ###Fig3.
#
# Looking at the gpa midpoint trends from 2018 to 2024, mechanical engineering and computer engineering show the highest GPAs across all years, also showing the clearest upward movement over time. Humanities fields like history and literature stay flatter with smaller changes. Relative to our hypothesis that stem majors tied to better job prospects seem to be drawing stronger applicants.
# The admission rate trends tell a slightly different story. Engineering majors consistently admit a smaller percentage of applicants. Some majors saw sharp drops in 2022, which might be related to the pandemic. A few majors have admit rates going up even as their GPAs rise, which could mean more seats opened up or more students applied. When GPA goes up and admit rate goes down together, that's a clearer sign of growing competition.

# %%
def trend_lines(df, col, title):
    years = [2018, 2020, 2022, 2024]
    plt.figure(figsize=(10,6))

    for m, g in df.dropna(subset=[col]).groupby("major"):
        g = g.sort_values("year")
        plt.plot(g["year"], g[col], marker="o", label=m)

    plt.title(title)
    plt.xlabel("Year")
    plt.ylabel(col)

    plt.xticks(years)
    plt.xlim(min(years)-0.2, max(years)+0.2)

    plt.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=11,       
        markerscale=1.4,    
        handlelength=2.2,   
        labelspacing=0.6  
    )
    plt.tight_layout()
    plt.show()

trend_lines(df, "gpa_mid", "Trend: GPA Midpoint by Major (2018, 2020, 2022, 2024)")
trend_lines(df, "admit_rate", "Trend: Admit Rate by Major (2018, 2020, 2022, 2024)")

# %% [markdown]
# ###Table1. and Table2.  Rate of Change in Admitted GPA Midpoints and Admit Rates for UC San Diego Transfer Students, by Major
#
# These two tables present the majors ranked by the fastest‑increasing admitted GPA midpoint, followed by the majors arranged in descending order. We selected biennial years (2018–2024) to examine medium‑term trends, and we discuss the two tables together here because both could help us evaluate the “selectivity” of a certain major. If we only consider the top five majors here(We also have the table which only shows the top five choices for each table but it's not necessary to be shown here): For the first table here, mechanical engineering (0.043), cognitive science (0.03475), bioengineering (0.02525), computer engineering (0.02425) and history (0.01775) show the steepest positive slope, meaning their admitted students’ GPA midpoint has been rising the quickest over the years, which suggest that stronger academic profiles are being admitted over time and these programs are becoming increasingly competitive for UC San Diego transfer students. Also, noted that the p-value here, only computer engineering has a p-value less than 0.5, which suggests the rise trend for computer engineering is unlikely to be due to random variations. For the second table here, Computer Engineering (-0.0655), Electrical Engineering (-0.0140), Chemistry (-0.008), Structural Engineering (-0.008), Mechanical Engineering (-0.008). These majors show the steepest negative slopes, meaning they are admitting a smaller percentage of applicants over time. It’s also interesting to see that the top 5 fastest increasing GPA midpoint and top 5 fastest decreasing admit rate doesn’t have exactly the same majors. In other words, A major might have a strong GPA trend but a weak admit‑rate trend, like History, shows up in the GPA‑increase list (GPA midpoint rising), but does not appear among the top decreasing admit‑rate majors, this could due to a GPA inflation in history, suggesting its selectivity might have not changed as dramatically. Meanwhile, a major might be decreasing in admit rate but not increasing in GPA midpoint, like Chemistry, shows up in the decreasing admit‑rate table, but not in the GPA‑increase list, meaning the academic profile of admitted students hasn’t risen as quickly. This could be there isn’t a big shift in the admitted student academic strengths, but only a sharp decrease in the program seats, like cuts of seats due to the funding cut. Another reason could be notice for the second table here, all the p value are much bigger than 0.05, (around 0.5) except for computer engineering major, which was also among the top five increasing admitted GPA, suggesting that this decreasing admit rate might could just be random noise. If we consider p-value only, then the only ones among these 15 majors in these two tables that have a p-value less than 0.05 are Drama and Applied Mathematics, which has a postive slope in admit rate slope,(slope more negative= become more selective) meaning the drop of their selectively is unlikely due to random factors.

# %%
def slope_table(df, y_col):
    rows = []
    for m, g in df.dropna(subset=["year", y_col]).groupby("major"):
        if g["year"].nunique() < 2:
            continue
        x = g["year"].astype(float).values
        y = g[y_col].astype(float).values
        slope, intercept, r, p, se = stats.linregress(x, y)
        rows.append({"major": m, "slope": slope, "p_value": p, "r": r, "n": len(g)})
    out = pd.DataFrame(rows).sort_values("slope", ascending=False)
    return out

gpa_slope = slope_table(df, "gpa_mid")
admit_slope = slope_table(df, "admit_rate")

print("GPA midpoint slope (higher = increasing selectivity):")
display(gpa_slope)

print("Admit rate slope (more negative = becoming more selective):")
display(admit_slope.sort_values("slope", ascending=True))
# Out:
# GPA midpoint slope (higher = increasing selectivity):
#                             major    slope   p_value         r  n
# 11         Mechanical Engineering  0.04300  0.203738  0.796262  4
# 3               Cognitive Science  0.03475  0.075692  0.924308  4
# 1                  Bioengineering  0.02525  0.266786  0.733214  4
# 4            Computer Engineering  0.02425  0.034575  0.965425  4
# 8                         History  0.01775  0.227850  0.772150  4
# 10                 Marine Biology  0.01450  0.227696  0.772304  4
# 2                       Chemistry  0.01275  0.147033  0.852967  4
# 12                  Public Health  0.01000  0.652108  0.347892  4
# 14            Visual Arts - Media  0.00825  0.695370  0.304630  4
# 0             Applied Mathematics  0.00725  0.475323  0.524677  4
# 6   Ecology, Behavior & Evolution  0.00525  0.796938  0.203062  4
# 5                           Drama  0.00425  0.541544  0.458456  4
# 7     Electrical Engineering - BS  0.00350  0.767952  0.232048  4
# 9              Literature/Writing  0.00175  0.912329  0.087671  4
# 13         Structural Engineering -0.00175  0.917590 -0.082410  4
# Admit rate slope (more negative = becoming more selective):
#                             major   slope   p_value         r  n
# 4            Computer Engineering -0.0655  0.050999 -0.949001  4
# 7     Electrical Engineering - BS -0.0140  0.561643 -0.438357  4
# 2                       Chemistry -0.0080  0.466667 -0.533333  4
# 13         Structural Engineering -0.0080  0.556240 -0.443760  4
# 11         Mechanical Engineering -0.0080  0.757129 -0.242871  4
# 10                 Marine Biology -0.0050  0.826447 -0.173553  4
# 9              Literature/Writing  0.0060  0.685946  0.314054  4
# 1                  Bioengineering  0.0120  0.621472  0.378528  4
# 5                           Drama  0.0215  0.012212  0.987788  4
# 6   Ecology, Behavior & Evolution  0.0225  0.191124  0.808876  4
# 8                         History  0.0225  0.185845  0.814155  4
# 14            Visual Arts - Media  0.0240  0.123644  0.876356  4
# 3               Cognitive Science  0.0270  0.076619  0.923381  4
# 0             Applied Mathematics  0.0275  0.041847  0.958153  4
# 12                  Public Health  0.0395  0.294390  0.705610  4

# %% [markdown]
# ###Fig4. Biennial UCSD Alumni Earnings Rankings of the Top 15 Major (2018–2024)
#
# In Figure 4, we used biennial data points from 2018 to 2024 to analyze medium term trends and generated four corresponding bar plots. In each plot, bar length denotes the median annual earnings of UC San Diego alumni within two years of earning a B.S. or B.A. degree. The data here demonstrate a highly stable earnings hierarchy across the 2018–2024 period. Engineering majors, particularly Computer Engineering and Electrical Engineering, consistently exhibit the highest median earnings, indicating sustained market demand for technical skill sets. Mid range earnings are observed for majors such as Bioengineering, Applied Mathematics, and Public Health. In contrast, majors in the arts, humanities, and certain life sciences remain at the lower end of the earnings distribution with minimal changes in rank over time. Overall, the persistence of these patterns suggests long term structural differences in labor market outcomes across disciplines. Another notable observation emerges when comparing the two arts majors. Both Visual Arts–Media and Drama declined sharply in 2020, but Drama rebounded while Visual Arts–Media continued to fall. This difference may be influenced by the rise of digital media and AI driven content creation during the pandemic, as well as renewed demand for live, in person performances that benefitted Drama. These trends (upgoing, keep dropping) may also affect how a student choose their majors (Would discuss more later on in section 2). However, the bar plot alone does not effectively illustrate the broader earnings distribution, including the 25th percentile (lower quartile) and 75th percentile (upper quartile) values. These measures may be relevant for students’ decision making, as students often focus on the minimum and maximum earning potentials rather than solely the median, thus this is why we would use the error bar plot below in Figure 5 to do further analyzation.

# %%
def earnings_topN_bar(df, year, col="earn_med", N=15, title=None):
    sub = df[df["year"] == year].dropna(subset=[col]).copy()
    sub = sub.sort_values(col, ascending=False).head(N)
    sub = sub.sort_values(col, ascending=True)  

    plt.figure(figsize=(10, 6))
    plt.barh(sub["major"], sub[col])
    plt.xlabel(col)
    plt.ylabel("Major")
    plt.title(title or f"Top {N} Majors by {col} ({year})")
    plt.tight_layout()
    plt.show()

for y in [2018, 2020, 2022, 2024]:
    earnings_topN_bar(df, y, col="earn_med", N=15)

# %% [markdown]
# ###Fig5. Annual Earnings by Major for UC San Diego Alumni Students, 2018–2024
#
# The four graphs here in Figure 5 display annual earnings by major for UC San Diego undergrad alumni among 15 specific majors, shown separately for the years 2018, 2020, 2022, and 2024. Each graph includes: A point representing the median annual earnings for each major and an error bar line showing the interquartile range (IQR) (25%-75% range), illustrating the spread or variability in earnings. Majors are ordered vertically, allowing easy comparison both within each year and across years.
# Across the four graphs (2018–2024), earnings outcomes for UC San Diego alumni show a stable and predictable pattern: engineering and technical majors consistently achieve the highest median salaries with the widest variation, while humanities and arts majors report lower but steady earnings with less variability. Most majors experience annual median salary increases over 2018-2022, but falls back in 2022-2024, which could be visualize by the green dots (median annual salary) is increasing meanwhile less tight in 2018-2022, and decreasing meanwhile tighter to each other in 2024.  We could see it the most obviously in the field of computer engineering, which goes from around 11k in 2018 to over 12k in 2020, but falls back to less than 12k in 2022 and around 10k in 2024, which was even worse than what’s in 2018, suggesting a worse labor market, which might due to the rise of AI. The relative positioning of majors remains largely unchanged, indicating that field of study continues to be a strong predictor of early career earnings. Moreover, for some majors, the green median marker consistently appears near the center of the blue interquartile range, suggesting that earnings for these fields may follow a roughly normal distribution. Bioengineering is one example. While for some majors, the green median maker swings from near the 25% to near the 75% over years, for example, chemistry here. This salary stability in the work field could also be a consideration for our students when choosing their majors. However, the yearly changes are not immediately apparent in these separate plots. Therefore, we employ a multi series time series line plot in Figure 6 below to more effectively visualize and represent the earnings trajectories over time.

# %%
def earnings_interval(df, year, title):
    sub = df[df["year"] == year].dropna(subset=["earn_med"]).sort_values("earn_med", ascending=False)
    y = range(len(sub))
    plt.figure(figsize=(10,6))
    
    plt.hlines(y, sub["earn_p25"], sub["earn_p75"])
    plt.plot(sub["earn_p25"], y, marker="|", linestyle="None")
    plt.plot(sub["earn_p75"], y, marker="|", linestyle="None")

    plt.plot(sub["earn_med"], y, marker="o", linestyle="None")
    plt.yticks(y, sub["major"])
    plt.title(title)
    plt.xlabel("Annual Earnings")
    plt.tight_layout()
    plt.show()

for y in years:
    earnings_interval(df, y, f"Earnings by Major with IQR ({y})")

# %% [markdown]
# ###Fig6.  Median Earnings Trends by Major at Biennial Intervals (2018–2024)
#
# In Figure 6, overall, biennial changes reinforce a stable hierarchy: engineering consistently leads, mid‑STEM majors remain in the center, and arts/humanities maintain lower but more volatile earnings profiles: Engineering majors remain the highest‑earning group. Computer Engineering rises from 2018 to a peak in 2020, then declines in 2022 and 2024. Electrical Engineering shows mild increases from 2018 to 2022 before a small decrease in 2024. Mechanical and Structural Engineering follow similar patterns with moderate growth to 2020–2022 and slight declines thereafter. Mid‑range majors display smaller but visible biennial shifts. Bioengineering and Applied Mathematics both increase into 2020, dip in 2022, and then stabilize or slightly recover by 2024. Marine Biology and Public Health trend gently downward after 2020, showing moderate erosion in earnings by 2024.Arts and humanities majors show the largest fluctuations. Visual Arts–Media increases sharply from 2018 to 2020 but then drops significantly in both 2022 and 2024, marking the steepest long‑term decline. Drama decreases from 2018 to 2020 but recovers steadily through 2022 and 2024. Literature/Writing and History show small, stable biennial changes across all years. It's also interesting to notice that some majors rise and fall along with each other, for example, Computer Engineering, Bioengineering and Applied Mathematics. This could be that either these majors are affected by the same factors or students graduate in one of these majors might tend to go to the other two fields here for work, for example a Computer Engineering major graduate might go to work for a Bioengineering company and an Applied Mathematics B.S holder is welcomed to enter a CSE related field.
# In both case we could see later on in section 2 whether these three majors have a trend in the relationship between admit rate, or GPA rate and earnings.

# %%
def earnings_trend_all_with_legend(df, col="earn_med", title=None):
    years = [2018, 2020, 2022, 2024]
    sub = df[df["year"].isin(years)].dropna(subset=[col]).copy()

    plt.figure(figsize=(12, 7))
    for m, g in sub.groupby("major"):
        g = g.sort_values("year")
        plt.plot(g["year"], g[col], marker="o", label=m)  

    plt.xticks(years)
    plt.xlabel("Year")
    plt.ylabel(col)
    plt.title(title or f"{col} Trend by Major (2018, 2020, 2022, 2024)")

    plt.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=11,       
        markerscale=1.4,   
        handlelength=2.2,  
        labelspacing=0.6   
    ) 
    plt.tight_layout()
    plt.show()

earnings_trend_all_with_legend(df, col="earn_med")

# %% [markdown]
# ### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %% [markdown]
# #### Merge Two Datasets

# %%
df = df_major.merge(df_earn, on=["major","year"], how="left")
display(df.head(10))
print("Merged shape:", df.shape)

missing = df[df["earn_med"].isna()]["major"].value_counts()
print("Majors missing earnings after merge:")
display(missing)
# Out:
#    year                        major  applicants  admits  enrollees  \
# 0  2024                      History         284     212         24
# 1  2024          Visual Arts - Media         263     176         63
# 2  2024         Computer Engineering         455     137         61
# 3  2024                    Chemistry         190      89         28
# 4  2024  Electrical Engineering - BS         412     161         68
# 5  2024               Bioengineering          95      41         14
# 6  2024            Cognitive Science         358     294        140
# 7  2024                Public Health         217     128         56
# 8  2024          Applied Mathematics         194     143         46
# 9  2024           Literature/Writing         153      90         13
#
#    admit_rate  yield_rate admit_gpa_range enrollee_gpa_range  gpa_low  \
# 0        0.75        0.11     3.41 - 3.96        3.16 - 3.72     3.41
# 1        0.67        0.36     3.41 - 3.88        3.44 - 3.82     3.41
# 2        0.30        0.45     3.70 - 3.97        3.72 - 3.93     3.70
# 3        0.47        0.31     3.41 - 3.98        3.40 - 3.69     3.41
# 4        0.39        0.42     3.51 - 3.95        3.40 - 3.82     3.51
# 5        0.43        0.34     3.74 - 3.98        3.62 - 3.91     3.74
# 6        0.82        0.48     3.50 - 3.93        3.38 - 3.90     3.50
# 7        0.59        0.44     3.34 - 3.81        3.25 - 3.61     3.34
# 8        0.74        0.32     3.55 - 3.97        3.32 - 3.80     3.55
# 9        0.59        0.14     3.43 - 3.90        3.24 - 3.82     3.43
#
#    gpa_high  gpa_mid  gpa_width  earn_med  earn_p25  earn_p75  earners_count  \
# 0      3.96    3.685       0.55   35933.0   21804.0   49697.0             61
# 1      3.88    3.645       0.47   36057.0   20440.0   49000.0             60
# 2      3.97    3.835       0.27  104844.0   76024.0  160505.0            156
# 3      3.98    3.695       0.57   56269.0   48061.0   71287.0             80
# 4      3.95    3.730       0.44   92359.0   79534.0  113449.0            172
# 5      3.98    3.860       0.24   61865.0   39206.0   83579.0             40
# 6      3.93    3.715       0.43   44596.0   30211.0   67291.0            153
# 7      3.81    3.575       0.47   45419.0   29155.0   62040.0             62
# 8      3.97    3.760       0.42   56440.0   32556.0   72668.0             60
# 9      3.90    3.665       0.47   38368.0   27740.0   50520.0             71
#
#    records_count
# 0             61
# 1             60
# 2            156
# 3             80
# 4            172
# 5             40
# 6            153
# 7             62
# 8             60
# 9             71
# Merged shape: (60, 18)
# Majors missing earnings after merge:
# Series([], Name: count, dtype: int64)

# %%
def corr_report(df, x, y):
    sub = df.dropna(subset=[x, y]).copy()
    n = len(sub)
    if n < 3:
        return {"n": n, "pearson_r": np.nan, "pearson_p": np.nan, "spearman_rho": np.nan, "spearman_p": np.nan}
    pear_r, pear_p = stats.pearsonr(sub[x], sub[y])
    spr_r, spr_p = stats.spearmanr(sub[x], sub[y])
    return {"n": n, "pearson_r": pear_r, "pearson_p": pear_p, "spearman_rho": spr_r, "spearman_p": spr_p}

pairs = [
    ("gpa_mid", "earn_med"),
    ("admit_rate", "earn_med"),
    ("gpa_width", "earn_med"),
    ("yield_rate", "earn_med"),
]

for x, y in pairs:
    print(f"{x} vs {y}:", corr_report(df, x, y))
# Out:
# gpa_mid vs earn_med: {'n': 60, 'pearson_r': 0.5478521278204677, 'pearson_p': 5.880999096433849e-06, 'spearman_rho': 0.6070207904813255, 'spearman_p': 2.7217161587700173e-07}
# admit_rate vs earn_med: {'n': 60, 'pearson_r': -0.3715169758212085, 'pearson_p': 0.003471107188523545, 'spearman_rho': -0.37933687190442056, 'spearman_p': 0.0027979264387458813}
# gpa_width vs earn_med: {'n': 60, 'pearson_r': -0.5372769711666672, 'pearson_p': 9.592649058860554e-06, 'spearman_rho': -0.6108332149034236, 'spearman_p': 2.1847568606859157e-07}
# yield_rate vs earn_med: {'n': 60, 'pearson_r': 0.241945138870127, 'pearson_p': 0.0625395568770128, 'spearman_rho': 0.29959273470527426, 'spearman_p': 0.020044563723040396}

# %%
def scatter_with_fit(df, x, y, title):
    sub = df.dropna(subset=[x, y, "year"]).copy()
    plt.figure(figsize=(7,5))
    for yr in sorted(sub["year"].unique()):
        s = sub[sub["year"] == yr]
        plt.scatter(s[x], s[y], label=str(int(yr)), alpha=0.85)

    slope, intercept, r, p, se = stats.linregress(sub[x].astype(float), sub[y].astype(float))
    xx = np.linspace(sub[x].min(), sub[x].max(), 100)
    yy = intercept + slope * xx
    plt.plot(xx, yy)

    plt.title(f"{title}\nFit: slope={slope:.3g}, r={r:.3g}, p={p:.3g}")
    plt.xlabel(x)
    plt.ylabel(y)
    plt.legend(title="Year")
    plt.tight_layout()
    plt.show()

scatter_with_fit(df, "gpa_mid", "earn_med", "GPA Midpoint vs Median Earnings")
scatter_with_fit(df, "admit_rate", "earn_med", "Admit Rate vs Median Earnings (lower=more selective)")

# %%
m1 = smf.ols("gpa_mid ~ earn_med", data=df).fit()
m2 = smf.ols("admit_rate ~ earn_med", data=df).fit()

print(m1.summary())
print(m2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                gpa_mid   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     24.87
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           5.88e-06
# Time:                        06:32:39   Log-Likelihood:                 57.999
# No. Observations:                  60   AIC:                            -112.0
# Df Residuals:                      58   BIC:                            -107.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5101      0.033    106.995      0.000       3.444       3.576
# earn_med    2.546e-06   5.11e-07      4.987      0.000    1.52e-06    3.57e-06
# ==============================================================================
# Omnibus:                        2.523   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.283   Jarque-Bera (JB):                1.894
# Skew:                           0.427   Prob(JB):                        0.388
# Kurtosis:                       3.165   Cond. No.                     1.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             admit_rate   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     9.287
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):            0.00347
# Time:                        06:32:39   Log-Likelihood:                 29.996
# No. Observations:                  60   AIC:                            -55.99
# Df Residuals:                      58   BIC:                            -51.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6769      0.052     12.938      0.000       0.572       0.782
# earn_med   -2.481e-06   8.14e-07     -3.048      0.003   -4.11e-06   -8.51e-07
# ==============================================================================
# Omnibus:                        1.844   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.398   Jarque-Bera (JB):                1.828
# Skew:                          -0.381   Prob(JB):                        0.401
# Kurtosis:                       2.614   Cond. No.                     1.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
m3 = smf.ols("gpa_mid ~ earn_med + year", data=df).fit()
m4 = smf.ols("admit_rate ~ earn_med + year", data=df).fit()

print(m3.summary())
print(m4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                gpa_mid   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     18.84
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           5.22e-07
# Time:                        06:32:39   Log-Likelihood:                 62.519
# No. Observations:                  60   AIC:                            -119.0
# Df Residuals:                      57   BIC:                            -112.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -27.6395     10.232     -2.701      0.009     -48.129      -7.150
# earn_med    2.618e-06   4.78e-07      5.474      0.000    1.66e-06    3.58e-06
# year           0.0154      0.005      3.044      0.004       0.005       0.026
# ==============================================================================
# Omnibus:                        1.248   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                0.843
# Skew:                           0.288   Prob(JB):                        0.656
# Kurtosis:                       3.076   Cond. No.                     5.82e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.82e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             admit_rate   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     4.755
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):             0.0123
# Time:                        06:32:39   Log-Likelihood:                 30.169
# No. Observations:                  60   AIC:                            -54.34
# Df Residuals:                      57   BIC:                            -48.06
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -9.4068     17.544     -0.536      0.594     -44.537      25.724
# earn_med   -2.458e-06    8.2e-07     -2.998      0.004    -4.1e-06   -8.16e-07
# year           0.0050      0.009      0.575      0.568      -0.012       0.022
# ==============================================================================
# Omnibus:                        1.950   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.377   Jarque-Bera (JB):                1.924
# Skew:                          -0.389   Prob(JB):                        0.382
# Kurtosis:                       2.594   Cond. No.                     5.82e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.82e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
m5 = smf.ols("gpa_mid ~ earn_med + year + C(major)", data=df).fit()
m6 = smf.ols("admit_rate ~ earn_med + year + C(major)", data=df).fit()

print(m5.summary())
print(m6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                gpa_mid   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.703
# Method:                 Least Squares   F-statistic:                     9.711
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           1.42e-09
# Time:                        06:32:39   Log-Likelihood:                 93.162
# No. Observations:                  60   AIC:                            -152.3
# Df Residuals:                      43   BIC:                            -116.7
# Df Model:                          16
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                   -24.8185      7.331     -3.385      0.002     -39.603     -10.034
# C(major)[T.Bioengineering]                    0.0633      0.047      1.338      0.188      -0.032       0.159
# C(major)[T.Chemistry]                        -0.0898      0.043     -2.096      0.042      -0.176      -0.003
# C(major)[T.Cognitive Science]                -0.1187      0.045     -2.610      0.012      -0.210      -0.027
# C(major)[T.Computer Engineering]             -0.0103      0.099     -0.104      0.918      -0.210       0.190
# C(major)[T.Drama]                            -0.1276      0.071     -1.801      0.079      -0.270       0.015
# C(major)[T.Ecology, Behavior & Evolution]    -0.1613      0.060     -2.690      0.010      -0.282      -0.040
# C(major)[T.Electrical Engineering - BS]      -0.0534      0.068     -0.782      0.438      -0.191       0.084
# C(major)[T.History]                          -0.1140      0.058     -1.950      0.058      -0.232       0.004
# C(major)[T.Literature/Writing]               -0.1340      0.059     -2.277      0.028      -0.253      -0.015
# C(major)[T.Marine Biology]                   -0.2702      0.059     -4.589      0.000      -0.389      -0.151
# C(major)[T.Mechanical Engineering]            0.0959      0.054      1.786      0.081      -0.012       0.204
# C(major)[T.Public Health]                    -0.1537      0.052     -2.967      0.005      -0.258      -0.049
# C(major)[T.Structural Engineering]           -0.1004      0.054     -1.848      0.072      -0.210       0.009
# C(major)[T.Visual Arts - Media]              -0.1166      0.058     -2.002      0.052      -0.234       0.001
# earn_med                                   1.547e-07   1.77e-06      0.087      0.931   -3.42e-06    3.73e-06
# year                                          0.0141      0.004      3.911      0.000       0.007       0.021
# ==============================================================================
# Omnibus:                        3.528   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.171   Jarque-Bera (JB):                2.654
# Skew:                          -0.482   Prob(JB):                        0.265
# Kurtosis:                       3.365   Cond. No.                     6.03e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.03e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             admit_rate   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     9.506
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           1.98e-09
# Time:                        06:32:39   Log-Likelihood:                 70.908
# No. Observations:                  60   AIC:                            -107.8
# Df Residuals:                      43   BIC:                            -72.21
# Df Model:                          16
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                   -13.3153     10.622     -1.253      0.217     -34.738       8.107
# C(major)[T.Bioengineering]                   -0.3006      0.068     -4.391      0.000      -0.439      -0.163
# C(major)[T.Chemistry]                        -0.1360      0.062     -2.191      0.034      -0.261      -0.011
# C(major)[T.Cognitive Science]                 0.1226      0.066      1.860      0.070      -0.010       0.255
# C(major)[T.Computer Engineering]             -0.2335      0.144     -1.626      0.111      -0.523       0.056
# C(major)[T.Drama]                             0.0570      0.103      0.555      0.582      -0.150       0.264
# C(major)[T.Ecology, Behavior & Evolution]    -0.1925      0.087     -2.215      0.032      -0.368      -0.017
# C(major)[T.Electrical Engineering - BS]      -0.1773      0.099     -1.793      0.080      -0.377       0.022
# C(major)[T.History]                           0.0761      0.085      0.898      0.374      -0.095       0.247
# C(major)[T.Literature/Writing]               -0.0011      0.085     -0.013      0.990      -0.173       0.171
# C(major)[T.Marine Biology]                   -0.2160      0.085     -2.532      0.015      -0.388      -0.044
# C(major)[T.Mechanical Engineering]           -0.4488      0.078     -5.766      0.000      -0.606      -0.292
# C(major)[T.Public Health]                    -0.0709      0.075     -0.944      0.350      -0.222       0.081
# C(major)[T.Structural Engineering]           -0.1494      0.079     -1.898      0.064      -0.308       0.009
# C(major)[T.Visual Arts - Media]               0.0134      0.084      0.158      0.875      -0.157       0.184
# earn_med                                   1.161e-06   2.57e-06      0.452      0.654   -4.02e-06    6.35e-06
# year                                          0.0069      0.005      1.312      0.196      -0.004       0.017
# ==============================================================================
# Omnibus:                        2.201   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.333   Jarque-Bera (JB):                1.397
# Skew:                          -0.306   Prob(JB):                        0.497
# Kurtosis:                       3.430   Cond. No.                     6.03e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.03e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
if "applicants" in df.columns:
    m7 = smf.ols("admit_rate ~ earn_med + year + applicants + C(major)", data=df).fit()
    print(m7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             admit_rate   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     8.958
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           4.34e-09
# Time:                        06:32:39   Log-Likelihood:                 71.490
# No. Observations:                  60   AIC:                            -107.0
# Df Residuals:                      42   BIC:                            -69.28
# Df Model:                          17
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                   -15.4752     10.908     -1.419      0.163     -37.488       6.538
# C(major)[T.Bioengineering]                   -0.3160      0.071     -4.471      0.000      -0.459      -0.173
# C(major)[T.Chemistry]                        -0.1331      0.062     -2.136      0.039      -0.259      -0.007
# C(major)[T.Cognitive Science]                 0.1404      0.069      2.038      0.048       0.001       0.279
# C(major)[T.Computer Engineering]             -0.2044      0.147     -1.386      0.173      -0.502       0.093
# C(major)[T.Drama]                             0.0386      0.105      0.369      0.714      -0.173       0.250
# C(major)[T.Ecology, Behavior & Evolution]    -0.2262      0.095     -2.389      0.021      -0.417      -0.035
# C(major)[T.Electrical Engineering - BS]      -0.1303      0.112     -1.165      0.250      -0.356       0.095
# C(major)[T.History]                           0.0817      0.085      0.960      0.342      -0.090       0.254
# C(major)[T.Literature/Writing]               -0.0181      0.087     -0.207      0.837      -0.195       0.158
# C(major)[T.Marine Biology]                   -0.2390      0.089     -2.680      0.010      -0.419      -0.059
# C(major)[T.Mechanical Engineering]           -0.3763      0.112     -3.369      0.002      -0.602      -0.151
# C(major)[T.Public Health]                    -0.0774      0.076     -1.024      0.312      -0.230       0.075
# C(major)[T.Structural Engineering]           -0.1520      0.079     -1.925      0.061      -0.311       0.007
# C(major)[T.Visual Arts - Media]               0.0179      0.085      0.212      0.833      -0.153       0.189
# earn_med                                   7.886e-07   2.61e-06      0.302      0.764   -4.48e-06    6.05e-06
# year                                          0.0080      0.005      1.480      0.146      -0.003       0.019
# applicants                                   -0.0002      0.000     -0.907      0.370      -0.001       0.000
# ==============================================================================
# Omnibus:                        2.008   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.366   Jarque-Bera (JB):                1.666
# Skew:                          -0.408   Prob(JB):                        0.435
# Kurtosis:                       2.964   Cond. No.                     6.18e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.18e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
years_keep = [2018, 2020, 2022, 2024]
df4 = df.copy()
df4["year"] = pd.to_numeric(df4["year"], errors="coerce").astype("Int64")
df4 = df4[df4["year"].isin(years_keep)].dropna(subset=["major","gpa_mid","admit_rate","earn_med"]).copy()
df4["year"] = df4["year"].astype(int)

print("Years in df4:", sorted(df4["year"].unique().tolist()))

# 2) pivot
w_gpa = df4.pivot_table(index="major", columns="year", values="gpa_mid", aggfunc="mean")
w_adm = df4.pivot_table(index="major", columns="year", values="admit_rate", aggfunc="mean")

print("Pivot GPA columns:", w_gpa.columns.tolist())
print("Pivot Admit columns:", w_adm.columns.tolist())

delta = pd.DataFrame({"major": w_gpa.index})

for y in years_keep:
    delta[f"gpa_mid_{y}"] = w_gpa[y].values
    delta[f"admit_rate_{y}"] = w_adm[y].values

delta["d_gpa_20_18"] = delta["gpa_mid_2020"] - delta["gpa_mid_2018"]
delta["d_gpa_22_20"] = delta["gpa_mid_2022"] - delta["gpa_mid_2020"]
delta["d_gpa_24_22"] = delta["gpa_mid_2024"] - delta["gpa_mid_2022"]

delta["d_adm_20_18"] = delta["admit_rate_2020"] - delta["admit_rate_2018"]
delta["d_adm_22_20"] = delta["admit_rate_2022"] - delta["admit_rate_2020"]
delta["d_adm_24_22"] = delta["admit_rate_2024"] - delta["admit_rate_2022"]

delta["d_gpa_24_18"] = delta["gpa_mid_2024"] - delta["gpa_mid_2018"]
delta["d_adm_24_18"] = delta["admit_rate_2024"] - delta["admit_rate_2018"]

earn_level_avg = df4.groupby("major", as_index=False)["earn_med"].mean().rename(columns={"earn_med":"earn_med_avg_18_24"})
earn_2024 = df4[df4["year"] == 2024][["major","earn_med"]].rename(columns={"earn_med":"earn_med_2024"})

delta = delta.merge(earn_level_avg, on="major", how="left").merge(earn_2024, on="major", how="left")

display(delta)
# Out:
# Years in df4: [2018, 2020, 2022, 2024]
# Pivot GPA columns: [2018, 2020, 2022, 2024]
# Pivot Admit columns: [2018, 2020, 2022, 2024]
#                             major  gpa_mid_2018  admit_rate_2018  \
# 0             Applied Mathematics         3.700             0.56
# 1                  Bioengineering         3.755             0.30
# 2                       Chemistry         3.605             0.50
# 3               Cognitive Science         3.490             0.68
# 4            Computer Engineering         3.685             0.65
# 5                           Drama         3.605             0.59
# 6   Ecology, Behavior & Evolution         3.560             0.33
# 7     Electrical Engineering - BS         3.680             0.51
# 8                         History         3.605             0.59
# 9              Literature/Writing         3.635             0.56
# 10                 Marine Biology         3.405             0.48
# 11         Mechanical Engineering         3.650             0.24
# 12                  Public Health         3.565             0.34
# 13         Structural Engineering         3.650             0.56
# 14            Visual Arts - Media         3.645             0.54
#
#     gpa_mid_2020  admit_rate_2020  gpa_mid_2022  admit_rate_2022  \
# 0          3.785             0.63         3.750             0.64
# 1          3.725             0.42         3.915             0.27
# 2          3.675             0.56         3.660             0.49
# 3          3.645             0.70         3.665             0.82
# 4          3.715             0.59         3.750             0.33
# 5          3.595             0.65         3.650             0.69
# 6          3.635             0.41         3.500             0.50
# 7          3.735             0.51         3.655             0.59
# 8          3.560             0.73         3.675             0.70
# 9          3.600             0.64         3.545             0.67
# 10         3.505             0.30         3.480             0.41
# 11         3.865             0.28         3.975             0.09
# 12         3.530             0.62         3.700             0.66
# 13         3.700             0.52         3.575             0.45
# 14         3.530             0.61         3.695             0.70
#
#     gpa_mid_2024  admit_rate_2024  d_gpa_20_18  d_gpa_22_20  d_gpa_24_22  \
# 0          3.760             0.74        0.085       -0.035        0.010
# 1          3.860             0.43       -0.030        0.190       -0.055
# 2          3.695             0.47        0.070       -0.015        0.035
# 3          3.715             0.82        0.155        0.020        0.050
# 4          3.835             0.30        0.030        0.035        0.085
# 5          3.615             0.72       -0.010        0.055       -0.035
# 6          3.640             0.45        0.075       -0.135        0.140
# 7          3.730             0.39        0.055       -0.080        0.075
# 8          3.685             0.75       -0.045        0.115        0.010
# 9          3.665             0.59       -0.035       -0.055        0.120
# 10         3.510             0.41        0.100       -0.025        0.030
# 11         3.900             0.25        0.215        0.110       -0.075
# 12         3.575             0.59       -0.035        0.170       -0.125
# 13         3.680             0.53        0.050       -0.125        0.105
# 14         3.645             0.67       -0.115        0.165       -0.050
#
#     d_adm_20_18  d_adm_22_20  d_adm_24_22  d_gpa_24_18  d_adm_24_18  \
# 0          0.07         0.01         0.10        0.060         0.18
# 1          0.12        -0.15         0.16        0.105         0.13
# 2          0.06        -0.07        -0.02        0.090        -0.03
# 3          0.02         0.12         0.00        0.225         0.14
# 4         -0.06        -0.26        -0.03        0.150        -0.35
# 5          0.06         0.04         0.03        0.010         0.13
# 6          0.08         0.09        -0.05        0.080         0.12
# 7          0.00         0.08        -0.20        0.050        -0.12
# 8          0.14        -0.03         0.05        0.080         0.16
# 9          0.08         0.03        -0.08        0.030         0.03
# 10        -0.18         0.11         0.00        0.105        -0.07
# 11         0.04        -0.19         0.16        0.250         0.01
# 12         0.28         0.04        -0.07        0.010         0.25
# 13        -0.04        -0.07         0.08        0.030        -0.03
# 14         0.07         0.09        -0.03        0.000         0.13
#
#     earn_med_avg_18_24  earn_med_2024
# 0             62627.75        56440.0
# 1             73938.00        61865.0
# 2             61369.75        56269.0
# 3             53949.75        44596.0
# 4            113012.00       104844.0
# 5             30795.00        34552.0
# 6             38944.00        36565.0
# 7             92602.75        92359.0
# 8             40166.00        35933.0
# 9             39865.75        38368.0
# 10            39822.75        43721.0
# 11            80934.75        83468.0
# 12            46156.50        45419.0
# 13            81522.25        82724.0
# 14            40361.50        36057.0

# %%
print("Spearman: earn_avg vs d_gpa_24_18 =",
      stats.spearmanr(delta["earn_med_avg_18_24"], delta["d_gpa_24_18"], nan_policy="omit"))

print("Spearman: earn_avg vs d_adm_24_18 =",
      stats.spearmanr(delta["earn_med_avg_18_24"], delta["d_adm_24_18"], nan_policy="omit"))

d1 = smf.ols("d_gpa_24_18 ~ earn_med_avg_18_24", data=delta).fit()
d2 = smf.ols("d_adm_24_18 ~ earn_med_avg_18_24", data=delta).fit()

print(d1.summary())
print(d2.summary())
# Out:
# Spearman: earn_avg vs d_gpa_24_18 = SignificanceResult(statistic=0.3285714285714285, pvalue=0.23180969720615968)
# Spearman: earn_avg vs d_adm_24_18 = SignificanceResult(statistic=-0.3838603617837837, pvalue=0.15779803162463046)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            d_gpa_24_18   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     2.297
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):              0.154
# Time:                        06:32:39   Log-Likelihood:                 19.351
# No. Observations:                  15   AIC:                            -34.70
# Df Residuals:                      13   BIC:                            -33.29
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0130      0.051      0.255      0.803      -0.097       0.123
# earn_med_avg_18_24  1.205e-06   7.95e-07      1.516      0.154   -5.13e-07    2.92e-06
# ==============================================================================
# Omnibus:                        4.573   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                2.589
# Skew:                           1.011   Prob(JB):                        0.274
# Kurtosis:                       3.231   Cond. No.                     1.77e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            d_adm_24_18   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     13.15
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):            0.00307
# Time:                        06:32:39   Log-Likelihood:                 12.838
# No. Observations:                  15   AIC:                            -21.68
# Df Residuals:                      13   BIC:                            -20.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.3113      0.079      3.956      0.002       0.141       0.481
# earn_med_avg_18_24 -4.452e-06   1.23e-06     -3.626      0.003    -7.1e-06    -1.8e-06
# ==============================================================================
# Omnibus:                        0.287   Durbin-Watson:                   1.590
# Prob(Omnibus):                  0.866   Jarque-Bera (JB):                0.422
# Skew:                          -0.244   Prob(JB):                        0.810
# Kurtosis:                       2.338   Cond. No.                     1.77e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /opt/conda/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)
# /opt/conda/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)

# %%
def scatter_fit(d, x, y, title):
    sub = d.dropna(subset=[x, y]).copy()
    slope, intercept, r, p, se = stats.linregress(sub[x], sub[y])
    plt.figure(figsize=(7,5))
    plt.scatter(sub[x], sub[y])
    xx = np.linspace(sub[x].min(), sub[x].max(), 100)
    plt.plot(xx, intercept + slope*xx)
    plt.title(f"{title}\n slope={slope:.3g}, r={r:.3g}, p={p:.3g}")
    plt.xlabel(x)
    plt.ylabel(y)
    plt.tight_layout()
    plt.show()

scatter_fit(delta, "earn_med_avg_18_24", "d_gpa_20_18", "Earnings avg vs ΔGPA (2020–2018)")
scatter_fit(delta, "earn_med_avg_18_24", "d_gpa_22_20", "Earnings avg vs ΔGPA (2022–2020)")
scatter_fit(delta, "earn_med_avg_18_24", "d_gpa_24_22", "Earnings avg vs ΔGPA (2024–2022)")

# %%
def summarize_model(model, term="earn_med"):
    b = model.params.get(term, np.nan)
    p = model.pvalues.get(term, np.nan)
    ci = model.conf_int().loc[term].tolist() if term in model.params.index else [np.nan, np.nan]
    r2 = model.rsquared
    n = int(model.nobs)
    return {"beta": b, "p": p, "ci_low": ci[0], "ci_high": ci[1], "R2": r2, "N": n}

print("m3 gpa_mid ~ earn_med + year:", summarize_model(m3, "earn_med"))
print("m4 admit_rate ~ earn_med + year:", summarize_model(m4, "earn_med"))
print("m5 gpa_mid ~ earn_med + year + C(major):", summarize_model(m5, "earn_med"))
print("m6 admit_rate ~ earn_med + year + C(major):", summarize_model(m6, "earn_med"))

if "m7" in globals():
    print("m7 admit_rate ~ earn_med + year + applicants + C(major):", summarize_model(m7, "earn_med"))
# Out:
# m3 gpa_mid ~ earn_med + year: {'beta': 2.617831579023334e-06, 'p': 1.0266694297049332e-06, 'ci_low': 1.6602079456609647e-06, 'ci_high': 3.5754552123857037e-06, 'R2': 0.398020585648456, 'N': 60}
# m4 admit_rate ~ earn_med + year: {'beta': -2.4581791162737793e-06, 'p': 0.004021762601180422, 'ci_low': -4.100088487938516e-06, 'ci_high': -8.162697446090426e-07, 'R2': 0.14299214231565227, 'N': 60}
# m5 gpa_mid ~ earn_med + year + C(major): {'beta': 1.5467620675611567e-07, 'p': 0.9309348369499901, 'ci_low': -3.423459717758696e-06, 'ci_high': 3.7328121312709274e-06, 'R2': 0.7832361455072692, 'N': 60}
# m6 admit_rate ~ earn_med + year + C(major): {'beta': 1.1613332015277056e-06, 'p': 0.6537430182120415, 'ci_low': -4.023440807092896e-06, 'ci_high': 6.346107210148307e-06, 'R2': 0.7795919915204139, 'N': 60}
# m7 admit_rate ~ earn_med + year + applicants + C(major): {'beta': 7.885899483326882e-07, 'p': 0.7639362500175332, 'ci_low': -4.4763253448689875e-06, 'ci_high': 6.053505241534364e-06, 'R2': 0.7838224563984808, 'N': 60}

# %%
d1 = smf.ols("d_gpa_24_18 ~ earn_med_avg_18_24", data=delta).fit()
d2 = smf.ols("d_adm_24_18 ~ earn_med_avg_18_24", data=delta).fit()

print(d1.summary())
print(d2.summary())

# Spearman（注意列名是 earn_med_avg_18_24）
print("Spearman (earn_med_avg_18_24 vs d_gpa_24_18):",
      stats.spearmanr(delta["earn_med_avg_18_24"], delta["d_gpa_24_18"], nan_policy="omit"))

print("Spearman (earn_med_avg_18_24 vs d_adm_24_18):",
      stats.spearmanr(delta["earn_med_avg_18_24"], delta["d_adm_24_18"], nan_policy="omit"))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            d_gpa_24_18   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     2.297
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):              0.154
# Time:                        06:32:40   Log-Likelihood:                 19.351
# No. Observations:                  15   AIC:                            -34.70
# Df Residuals:                      13   BIC:                            -33.29
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0130      0.051      0.255      0.803      -0.097       0.123
# earn_med_avg_18_24  1.205e-06   7.95e-07      1.516      0.154   -5.13e-07    2.92e-06
# ==============================================================================
# Omnibus:                        4.573   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                2.589
# Skew:                           1.011   Prob(JB):                        0.274
# Kurtosis:                       3.231   Cond. No.                     1.77e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            d_adm_24_18   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     13.15
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):            0.00307
# Time:                        06:32:40   Log-Likelihood:                 12.838
# No. Observations:                  15   AIC:                            -21.68
# Df Residuals:                      13   BIC:                            -20.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.3113      0.079      3.956      0.002       0.141       0.481
# earn_med_avg_18_24 -4.452e-06   1.23e-06     -3.626      0.003    -7.1e-06    -1.8e-06
# ==============================================================================
# Omnibus:                        0.287   Durbin-Watson:                   1.590
# Prob(Omnibus):                  0.866   Jarque-Bera (JB):                0.422
# Skew:                          -0.244   Prob(JB):                        0.810
# Kurtosis:                       2.338   Cond. No.                     1.77e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Spearman (earn_med_avg_18_24 vs d_gpa_24_18): SignificanceResult(statistic=0.3285714285714285, pvalue=0.23180969720615968)
# Spearman (earn_med_avg_18_24 vs d_adm_24_18): SignificanceResult(statistic=-0.3838603617837837, pvalue=0.15779803162463046)
# /opt/conda/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)
# /opt/conda/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)

# %%
years = [2018, 2020, 2022, 2024]

for y in years:
    sub = df[df["year"] == y].dropna(subset=["gpa_mid","earn_med","admit_rate","major"]).copy()
    if sub.empty:
        print(f"Year {y}: no data after dropna")
        continue

    # ---- GPA vs earnings ----
    slope, intercept, r, p, se = stats.linregress(sub["earn_med"], sub["gpa_mid"])
    xx = np.linspace(sub["earn_med"].min(), sub["earn_med"].max(), 100)

    plt.figure(figsize=(7,5))
    plt.scatter(sub["earn_med"], sub["gpa_mid"])
    plt.plot(xx, intercept + slope*xx)
    for _, row in sub.iterrows():
        plt.text(row["earn_med"], row["gpa_mid"], row["major"], fontsize=8)
    plt.xlabel("Median Annual Earnings")
    plt.ylabel("GPA Midpoint")
    plt.title(f"{y}: Earnings vs GPA Midpoint (r={r:.2f}, p={p:.3g})")
    plt.tight_layout()
    plt.show()

    # ---- Admit rate vs earnings ----
    slope, intercept, r, p, se = stats.linregress(sub["earn_med"], sub["admit_rate"])
    xx = np.linspace(sub["earn_med"].min(), sub["earn_med"].max(), 100)

    plt.figure(figsize=(7,5))
    plt.scatter(sub["earn_med"], sub["admit_rate"])
    plt.plot(xx, intercept + slope*xx)
    for _, row in sub.iterrows():
        plt.text(row["earn_med"], row["admit_rate"], row["major"], fontsize=8)
    plt.xlabel("Median Annual Earnings")
    plt.ylabel("Admit Rate")
    plt.title(f"{y}: Earnings vs Admit Rate (r={r:.2f}, p={p:.3g})")
    plt.tight_layout()
    plt.show()

# %%
YEARS = [2018, 2020, 2022, 2024]

def zscore(s: pd.Series) -> pd.Series:
    s = pd.to_numeric(s, errors="coerce")
    mu = s.mean()
    sd = s.std(ddof=0)
    if sd == 0 or np.isnan(sd):
        return (s - mu)  # all same -> 0-ish
    return (s - mu) / sd

def compute_yearly_scores(df: pd.DataFrame) -> pd.DataFrame:
    d = df[df["year"].isin(YEARS)].copy()

    # pick available columns
    cols = ["gpa_mid", "admit_rate"]
    if "earn_med" in d.columns:
        cols.append("earn_med")

    # keep only rows we can score (need gpa_mid & admit_rate at minimum)
    d[cols] = d[cols].apply(pd.to_numeric, errors="coerce")
    d = d.dropna(subset=["year", "major", "gpa_mid", "admit_rate"]).copy()

    # z-score within each year
    d["z_gpa"] = d.groupby("year")["gpa_mid"].transform(zscore)
    d["z_admit_inv"] = -d.groupby("year")["admit_rate"].transform(zscore)  # lower admit_rate => higher score

    if "earn_med" in d.columns:
        d["z_earn"] = d.groupby("year")["earn_med"].transform(zscore)
        d["selectivity_score_year"] = d["z_gpa"] + d["z_admit_inv"] + d["z_earn"]
    else:
        d["selectivity_score_year"] = d["z_gpa"] + d["z_admit_inv"]

    return d[["year", "major", "gpa_mid", "admit_rate"] + (["earn_med"] if "earn_med" in d.columns else []) + ["selectivity_score_year"]]

yearly = compute_yearly_scores(df)

# ---- aggregate across 4 years ----
agg = (yearly
       .groupby("major")
       .agg(
           years=("year", lambda x: sorted(x.unique().tolist())),
           n_years=("year", "nunique"),
           score_mean=("selectivity_score_year", "mean"),
           score_median=("selectivity_score_year", "median"),
       )
       .reset_index()
      )

# optional: only keep majors that appear in all 4 years
agg_all4 = agg[agg["n_years"] == 4].sort_values("score_mean", ascending=False)

display(agg_all4.head(20))
# Out:
#                             major                     years  n_years  \
# 11         Mechanical Engineering  [2018, 2020, 2022, 2024]        4
# 4            Computer Engineering  [2018, 2020, 2022, 2024]        4
# 1                  Bioengineering  [2018, 2020, 2022, 2024]        4
# 7     Electrical Engineering - BS  [2018, 2020, 2022, 2024]        4
# 13         Structural Engineering  [2018, 2020, 2022, 2024]        4
# 0             Applied Mathematics  [2018, 2020, 2022, 2024]        4
# 2                       Chemistry  [2018, 2020, 2022, 2024]        4
# 6   Ecology, Behavior & Evolution  [2018, 2020, 2022, 2024]        4
# 12                  Public Health  [2018, 2020, 2022, 2024]        4
# 14            Visual Arts - Media  [2018, 2020, 2022, 2024]        4
# 9              Literature/Writing  [2018, 2020, 2022, 2024]        4
# 10                 Marine Biology  [2018, 2020, 2022, 2024]        4
# 3               Cognitive Science  [2018, 2020, 2022, 2024]        4
# 8                         History  [2018, 2020, 2022, 2024]        4
# 5                           Drama  [2018, 2020, 2022, 2024]        4
#
#     score_mean  score_median
# 11    4.604901      4.909056
# 4     3.320481      3.296863
# 1     3.157984      3.161203
# 7     2.009633      2.142529
# 13    0.945919      0.963583
# 0     0.254276      0.238111
# 2     0.175431      0.218842
# 6    -0.830970     -0.709637
# 12   -1.384254     -1.543057
# 14   -1.771347     -1.936650
# 9    -1.822109     -1.742629
# 10   -1.843438     -1.701613
# 3    -2.084808     -1.864522
# 8    -2.209183     -2.064047
# 5    -2.522517     -2.494778

# %%
def coef_sentence(model, y_name):
    b = model.params["earn_med"]
    p = model.pvalues["earn_med"]
    return f"In the {y_name} model, earnings is associated with {y_name} (beta={b:.2e}, p={p:.3g}), controlling for year and major."

print(coef_sentence(m5, "gpa_mid"))
print(coef_sentence(m6, "admit_rate"))
if "m7" in globals():
    print(coef_sentence(m7, "admit_rate (with applicants)"))
# Out:
# In the gpa_mid model, earnings is associated with gpa_mid (beta=1.55e-07, p=0.931), controlling for year and major.
# In the admit_rate model, earnings is associated with admit_rate (beta=1.16e-06, p=0.654), controlling for year and major.
# In the admit_rate (with applicants) model, earnings is associated with admit_rate (with applicants) (beta=7.89e-07, p=0.764), controlling for year and major.

# %% [markdown]
# ## Ethics

# %% [markdown]
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#             Our admissions and earnings data may reflect structural inequalities, differences in applicant pools, and labor market demand. The systemic factors here may influence observed associations.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#             Our dataset contains only major-by-year aggregated statistics and no personally identifiable information.
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
#             Because we analyze aggregated data, we cannot evaluate individual-level fairness. We explicitly state this limitation in our discussion.
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#             Here, no data is collected individually, so we consider this as not applicable.
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#             Our data will be retained only for the duration of the course project.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#             Our analysis does not account for demographic factors, socioeconomic background, or non-monetary educational value.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#             We examined the data for possible sources: earnings may reflect broader economic trends, and admission rates may depend on applicant volume. These may confound interpretation.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#             We report correlations and regression results transparently and try our best to avoid causal claims.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#             All results we present are based on aggregated statistics; no individual data is displayed here.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#             All preprocessing and modeling steps we present are documented in the notebook to ensure reproducibility.
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#             Through our discussion and observation, we have ensured that our model does not rely on any unfairly discriminatory variables or substitute indicators.
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
#             Yes, we use multiple selectivity measures and regression models rather than relying on a single metric.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
#             Yes, we use an interpretable linear regression model to make our model easy to understand.
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#             Yes, we clearly stated that our data and research are based on UCSD data and have certain limitations.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
#             This is an academic analysis and not a deployed system.
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#             Findings could be misinterpreted as ranking majors solely by income; we caution against oversimplification.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Below is our Team Expectations
#
# ## Communication
#
# Primary Communication: WeChat will be our main communication platform. We will create a group chat for all project-related discussions. For important discussions, we may also schedule in-person meetings.
#
# Response Time: All team members are expected to respond to messages within 24 hours. If there is an urgent issue (e.g., upcoming deadline or ready check before submission), members should respond as soon as possible.
#
# Meetings: We will hold in-person meetings when necessary (especially before major deadlines). If someone cannot attend, they must inform the group in advance and review meeting notes afterward.
#
# Respectful Communication: We will communicate respectfully and professionally. It is okay to disagree, but we will discuss issues constructively and focus on problem-solving rather than personal criticism.
#
# ## Task Completion & Responsibility
#
# Each member is responsible for completing their assigned tasks on time.
#
# If someone anticipates difficulty meeting a deadline, they must inform the group as soon as possible so we can adjust responsibilities.
#
# We will use GitHub (Issues/Projects board) to track task progress and ensure transparency.
#
# All members should contribute meaningfully to coding, analysis, writing, and presentation work.
#
# ## Addressing Problems
#
# If a team member becomes unresponsive or does not complete tasks:
#
# First, we will check in privately to understand the situation.
#
# If the issue continues, we will discuss it as a group.
#
# If the problem persists and affects project progress, we will inform the TA and/or professor.
#
# ## Commitment
#
# All team members agree to:
#
# Communicate clearly and respectfully.
#
# Contribute fairly to the project.
#
# Support each other throughout the quarter.
#
# Work toward completing the project successfully and professionally.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time | Completed Before Meeting | Discuss at Meeting |
# |---|---|---|---|
# | 1/20 | 1 PM | Read COGS 108 expectations; brainstorm UCSD-focused research ideas | Finalize research question: UCSD transfer selectivity and major-level earnings |
# | 1/26 | 10 AM | Collect UCSD transfer admissions data and major-level earnings data | Review dataset structure; identify key variables (major, year, gpa_mid, admit_rate, earn_med, earn_p25, earn_p50, earn_p75) |
# | 2/1 | 10 AM | Begin data cleaning; convert percentages and currency formats | Discuss construction of selectivity metrics (GPA midpoint, admission rate); check missing values |
# | 2/18 | 3 PM | Complete full data cleaning and merge by major × year (due 2/16) | Confirm final cleaned dataset; verify merged variables and sample size, also make final checks for data checkpoint1. |
# | 2/23 | 12 PM | Complete EDA: trends in gpa_mid and admit_rate by major; earnings distributions | Interpret EDA results; refine hypotheses about selectivity–earnings relationship |
# | 2/28 | 4 PM | Zoom meeting discussing the EDA checkpoint | Plan out analysis: Pearson/Spearman correlations; OLS regressions (gpa_mid ~ earn_med, admit_rate ~ earn_med + year + C(major)) |
# | 3/10 | 12 PM | Run regression models; include year and major fixed effects | Interpret coefficients; discuss limitations and potential confounders |
# | 3/17 | 6 PM | Draft final results, discussion, and ethics section | Final review and edits before submission |
# | 3/18 | Before 11:59 PM | NA | Submit Final Project & Group Surveys |
